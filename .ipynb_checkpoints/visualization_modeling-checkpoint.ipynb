# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("Laptop_Data.csv")

# %%
df.head()
# Out:
#    Price Company Operating System  RAM   Type  Warranty  Inches TouchScreen  \
# 0  58990      HP        Windows11    8    N\A         1      16          NO
# 1  57990      HP        Windows11   16    N\A         1      16          NO
# 2  34490  Lenovo        Windows11    8    N\A         1      15          NO
# 3  32990      HP        Windows11    8    N\A         1      15          NO
# 4  54990    Acer        Windows11    8  Swift         1      14          NO
#
#    HDD    SSD  Generation Processor Type
# 0    0  512.0          11             i5
# 1    0  512.0          11             i5
# 2    0  512.0           0        Ryzen 5
# 3    0  512.0           0        Ryzen 3
# 4    0  512.0          12             i5

# %%
df.shape
# Out:
# (984, 12)

# %%
sns.displot(df["Price"], kde=True)

# %%
import matplotlib.pyplot as plt
sns.displot(df["Company"], kde=True)
plt.xticks(rotation = "vertical")
plt.show()

# %%
sns.barplot(x=df["Company"], y=df["Price"])
plt.xticks(rotation = "vertical")
plt.show()

# %%
sns.barplot(x=df["Generation"], y=df["Processor Type"])
# Out:
# <Axes: xlabel='Generation', ylabel='Processor Type'>

# %%
sns.barplot(x=df["SSD"], y=df["Price"])
# Out:
# <Axes: xlabel='SSD', ylabel='Price'>

# %%
sns.barplot(x=df["RAM"], y=df["Price"])
# Out:
# <Axes: xlabel='RAM', ylabel='Price'>

# %%
df.head()
# Out:
#    Price Company Operating System  RAM   Type  Warranty  Inches TouchScreen  \
# 0  58990      HP        Windows11    8    N\A         1      16          NO
# 1  57990      HP        Windows11   16    N\A         1      16          NO
# 2  34490  Lenovo        Windows11    8    N\A         1      15          NO
# 3  32990      HP        Windows11    8    N\A         1      15          NO
# 4  54990    Acer        Windows11    8  Swift         1      14          NO
#
#    HDD    SSD  Generation Processor Type
# 0    0  512.0          11             i5
# 1    0  512.0          11             i5
# 2    0  512.0           0        Ryzen 5
# 3    0  512.0           0        Ryzen 3
# 4    0  512.0          12             i5

# %%
sns.barplot(x=df["TouchScreen"], y=df["Price"])
# Out:
# <Axes: xlabel='TouchScreen', ylabel='Price'>

# %%
df["Price"].describe()
# Out:
# count       984.000000
# mean      70117.870935
# std       46917.403012
# min        9990.000000
# 25%       41365.000000
# 50%       58990.000000
# 75%       78990.000000
# max      450000.000000
# Name: Price, dtype: float64

# %%
df["Price"].plot(kind="box", title="Price")
# Out:
# <Axes: title={'center': 'Price'}>

# %%
len(df[df["Price"]>2.9e5])
# Out:
# 7

# %%
df = df[df["Price"]<2.9e5].reset_index(drop=True)

# %%
df["Price"].plot(kind="box", title="Price")
# Out:
# <Axes: title={'center': 'Price'}>

# %%
df = df[df["Price"]<2.8e5].reset_index(drop=True)

# %%
df["Price"].plot(kind="box", title="Price")
# Out:
# <Axes: title={'center': 'Price'}>

# %%
df["Price"].describe()
# Out:
# count       974.000000
# mean      67223.382957
# std       36953.759295
# min        9990.000000
# 25%       40990.000000
# 50%       58990.000000
# 75%       77365.000000
# max      244890.000000
# Name: Price, dtype: float64

# %%
df.shape
# Out:
# (974, 12)

# %%
df["Company"].value_counts()
# Out:
# Company
# HP           321
# Lenovo       196
# ASUS         161
# MSI          122
# DELL          53
# Acer          51
# Infinix       25
# APPLE         24
# SAMSUNG        9
# GIGABYTE       3
# realme         2
# Primebook      2
# CHUWI          2
# AXL            1
# Ultimus        1
# ALIENWARE      1
# Name: count, dtype: int64

# %%
df["Operating System"].value_counts()
# Out:
# Operating System
# Windows11       861
# Windows10        65
# Mac              24
# Chrome           11
# DOS              10
# Prime             1
# Android           1
# Linux/Ubuntu      1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Price Company Operating System  RAM   Type  Warranty  Inches TouchScreen  \
# 0  58990      HP        Windows11    8    N\A         1      16          NO
# 1  57990      HP        Windows11   16    N\A         1      16          NO
# 2  34490  Lenovo        Windows11    8    N\A         1      15          NO
# 3  32990      HP        Windows11    8    N\A         1      15          NO
# 4  54990    Acer        Windows11    8  Swift         1      14          NO
#
#    HDD    SSD  Generation Processor Type
# 0    0  512.0          11             i5
# 1    0  512.0          11             i5
# 2    0  512.0           0        Ryzen 5
# 3    0  512.0           0        Ryzen 3
# 4    0  512.0          12             i5

# %%
df.dtypes
# Out:
# Price                 int64
# Company              object
# Operating System     object
# RAM                   int64
# Type                 object
# Warranty              int64
# Inches                int64
# TouchScreen          object
# HDD                   int64
# SSD                 float64
# Generation            int64
# Processor Type       object
# dtype: object

# %%
df_encoded = pd.get_dummies(df, columns=['Company', 'Operating System', 'Type', 'TouchScreen', 'Processor Type'], drop_first=True)

# %%
sns.heatmap(df_encoded.corr())
# Out:
# <Axes: >

# %%
df_encoded.corr()["Price"]
# Out:
# Price                     1.000000
# RAM                       0.632041
# Warranty                       NaN
# Inches                    0.120184
# HDD                      -0.039335
#                             ...
# Processor Type_Ryzen 9    0.281851
# Processor Type_i3        -0.259331
# Processor Type_i5        -0.073016
# Processor Type_i7         0.468664
# Processor Type_i9         0.343168
# Name: Price, Length: 62, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 974 entries, 0 to 973
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price             974 non-null    int64
#  1   Company           974 non-null    object
#  2   Operating System  974 non-null    object
#  3   RAM               974 non-null    int64
#  4   Type              974 non-null    object
#  5   Warranty          974 non-null    int64
#  6   Inches            974 non-null    int64
#  7   TouchScreen       974 non-null    object
#  8   HDD               974 non-null    int64
#  9   SSD               958 non-null    float64
#  10  Generation        974 non-null    int64
#  11  Processor Type    974 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 91.4+ KB

# %%
sns.displot(df["Price"],kde=True)

# %%
import numpy as np
sns.displot(np.log(df["Price"]), kde=True)

# %%
X = df.drop(columns = ['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#     Company Operating System  RAM   Type  Warranty  Inches TouchScreen  HDD  \
# 0        HP        Windows11    8    N\A         1      16          NO    0
# 1        HP        Windows11   16    N\A         1      16          NO    0
# 2    Lenovo        Windows11    8    N\A         1      15          NO    0
# 3        HP        Windows11    8    N\A         1      15          NO    0
# 4      Acer        Windows11    8  Swift         1      14          NO    0
# ..      ...              ...  ...    ...       ...     ...         ...  ...
# 969    DELL        Windows11   16    XPS         1      13         YES    0
# 970      HP        Windows11    8    N\A         1      15          NO    0
# 971     MSI        Windows11   16    N\A         1      15          NO    0
# 972  Lenovo        Windows11   16    N\A         1      14          NO    0
# 973     MSI        Windows11   16    N\A         1      16          NO    0
#
#         SSD  Generation Processor Type
# ...

# %%
y
# Out:
# 0      10.985123
# 1      10.968026
# 2      10.448425
# 3      10.403960
# 4      10.914907
#          ...
# 969    11.849326
# 970    10.545078
# 971    11.001933
# 972    11.805520
# 973    12.043495
# Name: Price, Length: 974, dtype: float64

# %%
sns.displot(y, kde=True)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import r2_score, mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 974 entries, 0 to 973
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price             974 non-null    int64
#  1   Company           974 non-null    object
#  2   Operating System  974 non-null    object
#  3   RAM               974 non-null    int64
#  4   Type              974 non-null    object
#  5   Warranty          974 non-null    int64
#  6   Inches            974 non-null    int64
#  7   TouchScreen       974 non-null    object
#  8   HDD               974 non-null    int64
#  9   SSD               958 non-null    float64
#  10  Generation        974 non-null    int64
#  11  Processor Type    974 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 91.4+ KB

# %%
df['SSD'] = df['SSD'].fillna(0)

# %%
row_142 = df.iloc[142]

# %%
row_142
# Out:
# Price                   32990
# Company                    HP
# Operating System    Windows10
# RAM                         8
# Type                      N\A
# Warranty                    1
# Inches                     15
# TouchScreen                NO
# HDD                      1024
# SSD                       0.0
# Generation                 11
# Processor Type             i3
# Name: 142, dtype: object

# %%
nan_columns = df.isna().any()
nan_columns
# Out:
# Price               False
# Company             False
# Operating System    False
# RAM                 False
# Type                False
# Warranty            False
# Inches              False
# TouchScreen         False
# HDD                 False
# SSD                 False
# Generation          False
# Processor Type      False
# dtype: bool

# %%
df.head()
# Out:
#    Price Company Operating System  RAM   Type  Warranty  Inches TouchScreen  \
# 0  58990      HP        Windows11    8    N\A         1      16          NO
# 1  57990      HP        Windows11   16    N\A         1      16          NO
# 2  34490  Lenovo        Windows11    8    N\A         1      15          NO
# 3  32990      HP        Windows11    8    N\A         1      15          NO
# 4  54990    Acer        Windows11    8  Swift         1      14          NO
#
#    HDD    SSD  Generation Processor Type
# 0    0  512.0          11             i5
# 1    0  512.0          11             i5
# 2    0  512.0           0        Ryzen 5
# 3    0  512.0           0        Ryzen 3
# 4    0  512.0          12             i5

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 2)

# %% [markdown]
# ## LinearRegression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,6,10]),
    ('imputer', SimpleImputer(strategy='mean'), [2, 4, 5, 7, 8, 9])
     ],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8699802492735946
# MAE 0.12744711876076667

# %% [markdown]
# ## RandomForest

# %%
# step1 = ColumnTransformer(transformers=[
#     ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,6,10]),
#     ('imputer', SimpleImputer(strategy='mean'), [2, 4, 5, 7, 8, 9])
#      ],remainder='passthrough')

# step2 = RandomForestRegressor(
#     n_estimators = 100,
#     random_state = 3,
#     max_samples = 0.5,
#     max_features = 0.75,
#     max_depth = 15
# )

# pipe = Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])

# pipe.fit(X_train,y_train)

# y_pred = pipe.predict(X_test)

# print('R2 score',r2_score(y_test,y_pred))
# print('MAE',mean_absolute_error(y_test,y_pred))

# %%
import pickle

# %%
# pickle.dump(df,open('df.pkl','wb'))
# pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
X_train
# Out:
#      Company Operating System  RAM     Type  Warranty  Inches TouchScreen  \
# 396       HP        Windows11    8      N\A         1      15          NO
# 595   Lenovo        Windows11   16  IdeaPad         1      14          NO
# 142       HP        Windows10    8      N\A         1      15          NO
# 279      MSI        Windows11    8      N\A         1      14          NO
# 496       HP        Windows11    8      N\A         1      15          NO
# ..       ...              ...  ...      ...       ...     ...         ...
# 534       HP        Windows11    8      N\A         1      15          NO
# 584   Lenovo        Windows11   16      N\A         1      15          NO
# 493       HP        Windows11    8      N\A         1      15          NO
# 527  SAMSUNG        Windows11   16      N\A         1      15          NO
# 168   Lenovo        Windows11   16  IdeaPad         1      15          NO
#
#       HDD    SSD  Generation Processor Type
# ...

# %%
df
# Out:
#       Price Company Operating System  RAM   Type  Warranty  Inches  \
# 0     58990      HP        Windows11    8    N\A         1      16
# 1     57990      HP        Windows11   16    N\A         1      16
# 2     34490  Lenovo        Windows11    8    N\A         1      15
# 3     32990      HP        Windows11    8    N\A         1      15
# 4     54990    Acer        Windows11    8  Swift         1      14
# ..      ...     ...              ...  ...    ...       ...     ...
# 969  139990    DELL        Windows11   16    XPS         1      13
# 970   37990      HP        Windows11    8    N\A         1      15
# 971   59990     MSI        Windows11   16    N\A         1      15
# 972  133990  Lenovo        Windows11   16    N\A         1      14
# 973  169990     MSI        Windows11   16    N\A         1      16
#
#     TouchScreen  HDD     SSD  Generation Processor Type
# 0            NO    0   512.0          11             i5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 974 entries, 0 to 973
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price             974 non-null    int64
#  1   Company           974 non-null    object
#  2   Operating System  974 non-null    object
#  3   RAM               974 non-null    int64
#  4   Type              974 non-null    object
#  5   Warranty          974 non-null    int64
#  6   Inches            974 non-null    int64
#  7   TouchScreen       974 non-null    object
#  8   HDD               974 non-null    int64
#  9   SSD               974 non-null    float64
#  10  Generation        974 non-null    int64
#  11  Processor Type    974 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 91.4+ KB

# %%
df["SSD"].describe()
# Out:
# count     974.000000
# mean      532.895277
# std       186.021922
# min         0.000000
# 25%       512.000000
# 50%       512.000000
# 75%       512.000000
# max      2048.000000
# Name: SSD, dtype: float64

# %%
df["HDD"].describe()
# Out:
# count     974.000000
# mean       23.129363
# std       152.227766
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max      1024.000000
# Name: HDD, dtype: float64
