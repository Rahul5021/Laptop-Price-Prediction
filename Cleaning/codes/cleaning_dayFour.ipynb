# %%
import pandas as pd

# %%
df = pd.read_csv("phaseOne_cleaned.csv")

# %%
df.head()
# Out:
#    Price Company                           Processor  \
# 0  58990      HP  Intel Core i5 Processor (11th Gen)
# 1  57990      HP  Intel Core i5 Processor (11th Gen)
# 2  34490  Lenovo     AMD Ryzen 5 Hexa Core Processor
# 3  32990      HP     AMD Ryzen 3 Dual Core Processor
# 4  54990    Acer  Intel Core i5 Processor (12th Gen)
#
#               Operating System              RAM                       Display  \
# 0  Windows 11 Operating System    8 GB DDR4 RAM  40.89 cm (16.1 Inch) Display
# 1  Windows 11 Operating System   16 GB DDR4 RAM  40.89 cm (16.1 Inch) Display
# 2  Windows 11 Operating System    8 GB DDR4 RAM  39.62 cm (15.6 Inch) Display
# 3  Windows 11 Operating System    8 GB DDR4 RAM  39.62 cm (15.6 Inch) Display
# 4  Windows 11 Operating System  8 GB LPDDR5 RAM    35.56 cm (14 Inch) Display
#
#       Storage   Type                Warranty
# 0  512 GB SSD    N\A  1 Year Onsite Warranty
# 1  512 GB SSD    N\A  1 Year Onsite Warranty
# ...

# %%
for ram in df["RAM"]:
    print(type(ram))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
df["RAM"] = df["RAM"].str.replace("RAM", "")

# %%
df.head()
# Out:
#    Price Company                           Processor  \
# 0  58990      HP  Intel Core i5 Processor (11th Gen)
# 1  57990      HP  Intel Core i5 Processor (11th Gen)
# 2  34490  Lenovo     AMD Ryzen 5 Hexa Core Processor
# 3  32990      HP     AMD Ryzen 3 Dual Core Processor
# 4  54990    Acer  Intel Core i5 Processor (12th Gen)
#
#               Operating System           RAM                       Display  \
# 0  Windows 11 Operating System    8 GB DDR4   40.89 cm (16.1 Inch) Display
# 1  Windows 11 Operating System   16 GB DDR4   40.89 cm (16.1 Inch) Display
# 2  Windows 11 Operating System    8 GB DDR4   39.62 cm (15.6 Inch) Display
# 3  Windows 11 Operating System    8 GB DDR4   39.62 cm (15.6 Inch) Display
# 4  Windows 11 Operating System  8 GB LPDDR5     35.56 cm (14 Inch) Display
#
#       Storage   Type                Warranty
# 0  512 GB SSD    N\A  1 Year Onsite Warranty
# 1  512 GB SSD    N\A  1 Year Onsite Warranty
# 2  512 GB SSD    N\A  1 Year Onsite Warranty
# ...

# %%
for ram in df["RAM"]:
    print(ram)
# Out:
# 8 GB DDR4
# 16 GB DDR4
# 8 GB DDR4
# 8 GB DDR4
# 8 GB LPDDR5
# 8 GB DDR4
# 8 GB DDR4
# 8 GB DDR4
# 8 GB DDR4
# 8 GB DDR4
# 16 GB DDR5
# 8 GB DDR4
# 4 GB DDR4
# 16 GB DDR4
# 16 GB DDR4
# 8 GB DDR4
# 16 GB DDR4
# 16 GB DDR4
# 8 GB DDR4
# 8 GB DDR4
# 16 GB LPDDR4X
# 16 GB LPDDR5
# 8 GB DDR4
# 16 GB DDR4
# 8 GB DDR4
# 8 GB DDR4
# 8 GB DDR4
# 8 GB DDR4
# 16 GB DDR4
# 8 GB LPDDR5
# 16 GB DDR5
# 8 GB DDR4
# 8 GB DDR4
# 8 GB DDR4
# 16 GB DDR4
# 16 GB LPDDR4X
# 8 GB DDR4
# 16 GB DDR4
# 8 GB DDR4
# 8 GB DDR4
# 16 GB LPDDR4X
# 16 GB DDR4
# 8 GB DDR4
# 8 GB DDR4
# 8 GB DDR4
# 8 GB DDR4
# 16 GB LPDDR5
# 16 GB DDR
# 16 GB DDR
# 16 GB DDR4
# 8 GB DDR4
# 16 GB DDR4
# 8 GB LPDDR4X
# 8 GB DDR4
# 16 GB DDR4
# 16 GB LPDDR4X
# 8 GB DDR4
# 16 GB DDR4
# 8 GB DDR4
# 8 GB DDR4
# 8 GB DDR4
# 8 GB DDR4
# 8 GB LPDDR4X
# 8 GB DDR4
# 16 GB DDR4
# 16 GB LPDDR4X
# 8 GB DDR4
# 16 GB DDR4
# 8 GB DDR4
# LPDDR5  -faster & low power consuming
# 8 GB DDR4
# 16 GB DDR5
# 16 GB DDR4
# 16 GB DDR4
# 4 GB LPDDR4X
# ...

# %%
df["RAM"] = df["RAM"].str.replace("DDR4", "")

# %%
df.head()
# Out:
#    Price Company                           Processor  \
# 0  58990      HP  Intel Core i5 Processor (11th Gen)
# 1  57990      HP  Intel Core i5 Processor (11th Gen)
# 2  34490  Lenovo     AMD Ryzen 5 Hexa Core Processor
# 3  32990      HP     AMD Ryzen 3 Dual Core Processor
# 4  54990    Acer  Intel Core i5 Processor (12th Gen)
#
#               Operating System           RAM                       Display  \
# 0  Windows 11 Operating System        8 GB    40.89 cm (16.1 Inch) Display
# 1  Windows 11 Operating System       16 GB    40.89 cm (16.1 Inch) Display
# 2  Windows 11 Operating System        8 GB    39.62 cm (15.6 Inch) Display
# 3  Windows 11 Operating System        8 GB    39.62 cm (15.6 Inch) Display
# 4  Windows 11 Operating System  8 GB LPDDR5     35.56 cm (14 Inch) Display
#
#       Storage   Type                Warranty
# 0  512 GB SSD    N\A  1 Year Onsite Warranty
# 1  512 GB SSD    N\A  1 Year Onsite Warranty
# 2  512 GB SSD    N\A  1 Year Onsite Warranty
# ...

# %%
print(df["RAM"])
# Out:
# 0             8 GB
# 1            16 GB
# 2             8 GB
# 3             8 GB
# 4       8 GB LPDDR5
#            ...
# 979          16 GB
# 980           8 GB
# 981       16 GB DDR
# 982          16 GB
# 983    16 GB LPDDR5
# Name: RAM, Length: 984, dtype: object

# %%
df.head()
# Out:
#    Price Company                           Processor  \
# 0  58990      HP  Intel Core i5 Processor (11th Gen)
# 1  57990      HP  Intel Core i5 Processor (11th Gen)
# 2  34490  Lenovo     AMD Ryzen 5 Hexa Core Processor
# 3  32990      HP     AMD Ryzen 3 Dual Core Processor
# 4  54990    Acer  Intel Core i5 Processor (12th Gen)
#
#               Operating System           RAM                       Display  \
# 0  Windows 11 Operating System        8 GB    40.89 cm (16.1 Inch) Display
# 1  Windows 11 Operating System       16 GB    40.89 cm (16.1 Inch) Display
# 2  Windows 11 Operating System        8 GB    39.62 cm (15.6 Inch) Display
# 3  Windows 11 Operating System        8 GB    39.62 cm (15.6 Inch) Display
# 4  Windows 11 Operating System  8 GB LPDDR5     35.56 cm (14 Inch) Display
#
#       Storage   Type                Warranty
# 0  512 GB SSD    N\A  1 Year Onsite Warranty
# 1  512 GB SSD    N\A  1 Year Onsite Warranty
# 2  512 GB SSD    N\A  1 Year Onsite Warranty
# ...

# %%
df["RAM"]
# Out:
# 0             8 GB
# 1            16 GB
# 2             8 GB
# 3             8 GB
# 4       8 GB LPDDR5
#            ...
# 979          16 GB
# 980           8 GB
# 981       16 GB DDR
# 982          16 GB
# 983    16 GB LPDDR5
# Name: RAM, Length: 984, dtype: object

# %%
import re

# %%
df["RAM"] = df["RAM"].apply(lambda x: re.search(r'\d+', str(x)).group()).astype(int)

# %%
df.head()
# Out:
#    Price Company                           Processor  \
# 0  58990      HP  Intel Core i5 Processor (11th Gen)
# 1  57990      HP  Intel Core i5 Processor (11th Gen)
# 2  34490  Lenovo     AMD Ryzen 5 Hexa Core Processor
# 3  32990      HP     AMD Ryzen 3 Dual Core Processor
# 4  54990    Acer  Intel Core i5 Processor (12th Gen)
#
#               Operating System  RAM                       Display     Storage  \
# 0  Windows 11 Operating System    8  40.89 cm (16.1 Inch) Display  512 GB SSD
# 1  Windows 11 Operating System   16  40.89 cm (16.1 Inch) Display  512 GB SSD
# 2  Windows 11 Operating System    8  39.62 cm (15.6 Inch) Display  512 GB SSD
# 3  Windows 11 Operating System    8  39.62 cm (15.6 Inch) Display  512 GB SSD
# 4  Windows 11 Operating System    8    35.56 cm (14 Inch) Display  512 GB SSD
#
#     Type                Warranty
# 0    N\A  1 Year Onsite Warranty
# 1    N\A  1 Year Onsite Warranty
# 2    N\A  1 Year Onsite Warranty
# 3    N\A  1 Year Onsite Warranty
# ...

# %%
df["RAM"].unique()
# Out:
# array([ 8, 16,  4,  5, 32, 64])

# %%
for ram in df["RAM"]:
    print(ram)
# Out:
# 8
# 16
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 16
# 8
# 4
# 16
# 16
# 8
# 16
# 16
# 8
# 8
# 16
# 16
# 8
# 16
# 8
# 8
# 8
# 8
# 16
# 8
# 16
# 8
# 8
# 8
# 16
# 16
# 8
# 16
# 8
# 8
# 16
# 16
# 8
# 8
# 8
# 8
# 16
# 16
# 16
# 16
# 8
# 16
# 8
# 8
# 16
# 16
# 8
# 16
# 8
# 8
# 8
# 8
# 8
# 8
# 16
# 16
# 8
# 16
# 8
# 5
# 8
# 16
# 16
# 16
# 4
# 16
# 8
# 16
# 16
# 8
# 8
# 8
# 8
# 16
# 8
# 8
# 8
# 16
# 8
# 8
# 8
# 16
# 8
# 16
# 8
# 8
# 8
# 16
# 8
# 16
# 8
# 8
# 8
# 8
# 8
# 16
# 8
# 16
# 8
# 16
# 8
# 16
# 8
# 8
# 8
# 8
# 8
# 16
# 16
# 16
# 16
# 16
# 16
# 8
# 8
# 16
# 16
# 16
# 8
# 16
# 8
# 8
# 8
# 8
# 8
# 16
# 8
# 8
# 8
# 16
# 16
# 16
# 8
# 8
# 8
# 16
# 8
# 16
# 32
# 16
# 8
# 16
# 8
# 8
# 8
# 16
# 8
# 8
# 16
# 16
# 16
# 16
# 8
# 8
# 8
# 16
# 16
# 16
# 16
# 16
# 16
# 8
# 16
# 8
# 16
# 8
# 8
# 8
# 4
# 16
# 8
# 16
# 8
# 4
# 16
# 8
# 8
# 16
# 8
# 16
# 8
# 16
# 8
# 16
# 16
# 4
# 8
# 16
# 8
# 8
# 8
# 16
# 8
# 8
# 16
# 8
# 8
# 8
# 8
# 8
# 16
# 16
# 8
# 4
# 16
# 16
# 16
# 8
# 8
# 16
# 8
# 8
# 8
# 8
# 4
# 8
# 8
# ...

# %%
df["RAM"][69] = 8
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11132\3123235333.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["RAM"][69] = 8

# %%
df["RAM"].unique()
# Out:
# array([ 8, 16,  4, 32, 64])

# %%
for ram in df["RAM"]:
    print(type(ram))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# ...

# %%
df.head()
# Out:
#    Price Company                           Processor  \
# 0  58990      HP  Intel Core i5 Processor (11th Gen)
# 1  57990      HP  Intel Core i5 Processor (11th Gen)
# 2  34490  Lenovo     AMD Ryzen 5 Hexa Core Processor
# 3  32990      HP     AMD Ryzen 3 Dual Core Processor
# 4  54990    Acer  Intel Core i5 Processor (12th Gen)
#
#               Operating System  RAM                       Display     Storage  \
# 0  Windows 11 Operating System    8  40.89 cm (16.1 Inch) Display  512 GB SSD
# 1  Windows 11 Operating System   16  40.89 cm (16.1 Inch) Display  512 GB SSD
# 2  Windows 11 Operating System    8  39.62 cm (15.6 Inch) Display  512 GB SSD
# 3  Windows 11 Operating System    8  39.62 cm (15.6 Inch) Display  512 GB SSD
# 4  Windows 11 Operating System    8    35.56 cm (14 Inch) Display  512 GB SSD
#
#     Type                Warranty
# 0    N\A  1 Year Onsite Warranty
# 1    N\A  1 Year Onsite Warranty
# 2    N\A  1 Year Onsite Warranty
# 3    N\A  1 Year Onsite Warranty
# ...

# %%
df
# Out:
#       Price Company                           Processor  \
# 0     58990      HP  Intel Core i5 Processor (11th Gen)
# 1     57990      HP  Intel Core i5 Processor (11th Gen)
# 2     34490  Lenovo     AMD Ryzen 5 Hexa Core Processor
# 3     32990      HP     AMD Ryzen 3 Dual Core Processor
# 4     54990    Acer  Intel Core i5 Processor (12th Gen)
# ..      ...     ...                                 ...
# 979  139990    DELL  Intel Core i5 Processor (12th Gen)
# 980   37990      HP     AMD Ryzen 3 Quad Core Processor
# 981   59990     MSI     AMD Ryzen 7 Octa Core Processor
# 982  133990  Lenovo  Intel Core i7 Processor (12th Gen)
# 983  169990     MSI  Intel Core i7 Processor (13th Gen)
#
#                        Operating System  RAM  \
# 0           Windows 11 Operating System    8
# 1           Windows 11 Operating System   16
# 2           Windows 11 Operating System    8
# 3           Windows 11 Operating System    8
# 4           Windows 11 Operating System    8
# ...

# %%
import seaborn as sns

# %%
sns.displot(df["RAM"], kde = True)
# Out:
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df["RAM"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='RAM'>

# %%
import matplotlib.pyplot as plt
sns.barplot(x=df["RAM"], y = df["Price"])
plt.xticks(rotation="vertical")
plt.show()
# Out:
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
df.to_csv("dayFour_cleaning.csv", index=False)
