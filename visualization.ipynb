# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("Laptop_Data.csv")

# %%
df.head()
# Out:
#    Price Company Operating System  RAM   Type  Warranty  Inches TouchScreen  \
# 0  58990      HP        Windows11    8    N\A         1      16          NO
# 1  57990      HP        Windows11   16    N\A         1      16          NO
# 2  34490  Lenovo        Windows11    8    N\A         1      15          NO
# 3  32990      HP        Windows11    8    N\A         1      15          NO
# 4  54990    Acer        Windows11    8  Swift         1      14          NO
#
#    HDD    SSD  Generation Processor Type
# 0    0  512.0          11             i5
# 1    0  512.0          11             i5
# 2    0  512.0           0        Ryzen 5
# 3    0  512.0           0        Ryzen 3
# 4    0  512.0          12             i5

# %%
df.shape
# Out:
# (984, 12)

# %%
sns.displot(df["Price"], kde=True)
# Out:
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import matplotlib.pyplot as plt
sns.displot(df["Company"], kde=True)
plt.xticks(rotation = "vertical")
plt.show()
# Out:
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.barplot(x=df["Company"], y=df["Price"])
plt.xticks(rotation = "vertical")
plt.show()
# Out:
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.barplot(x=df["Generation"], y=df["Processor Type"])
# Out:
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Generation', ylabel='Processor Type'>

# %%
sns.barplot(x=df["SSD"], y=df["Price"])
# Out:
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='SSD', ylabel='Price'>

# %%
sns.barplot(x=df["RAM"], y=df["Price"])
# Out:
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='RAM', ylabel='Price'>

# %%
df.head()
# Out:
#    Price Company Operating System  RAM   Type  Warranty  Inches TouchScreen  \
# 0  58990      HP        Windows11    8    N\A         1      16          NO
# 1  57990      HP        Windows11   16    N\A         1      16          NO
# 2  34490  Lenovo        Windows11    8    N\A         1      15          NO
# 3  32990      HP        Windows11    8    N\A         1      15          NO
# 4  54990    Acer        Windows11    8  Swift         1      14          NO
#
#    HDD    SSD  Generation Processor Type
# 0    0  512.0          11             i5
# 1    0  512.0          11             i5
# 2    0  512.0           0        Ryzen 5
# 3    0  512.0           0        Ryzen 3
# 4    0  512.0          12             i5

# %%
sns.barplot(x=df["TouchScreen"], y=df["Price"])
# Out:
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\OneDrive - Tribhuvan University\Desktop\JupyterTtrl\pythonProject\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='TouchScreen', ylabel='Price'>

# %%
df["Price"].describe()
# Out:
# count       984.000000
# mean      70117.870935
# std       46917.403012
# min        9990.000000
# 25%       41365.000000
# 50%       58990.000000
# 75%       78990.000000
# max      450000.000000
# Name: Price, dtype: float64

# %%
df["Price"].plot(kind="box", title="Price")
# Out:
# <Axes: title={'center': 'Price'}>

# %%
len(df[df["Price"]>2.9e5])
# Out:
# 7

# %%
df = df[df["Price"]<2.9e5].reset_index(drop=True)

# %%
df["Price"].plot(kind="box", title="Price")
# Out:
# <Axes: title={'center': 'Price'}>

# %%
df = df[df["Price"]<2.8e5].reset_index(drop=True)

# %%
df["Price"].plot(kind="box", title="Price")
# Out:
# <Axes: title={'center': 'Price'}>

# %%
df["Price"].describe()
# Out:
# count       974.000000
# mean      67223.382957
# std       36953.759295
# min        9990.000000
# 25%       40990.000000
# 50%       58990.000000
# 75%       77365.000000
# max      244890.000000
# Name: Price, dtype: float64

# %%
df.shape
# Out:
# (974, 12)

# %%
df["Company"].value_counts()
# Out:
# Company
# HP           321
# Lenovo       196
# ASUS         161
# MSI          122
# DELL          53
# Acer          51
# Infinix       25
# APPLE         24
# SAMSUNG        9
# GIGABYTE       3
# realme         2
# Primebook      2
# CHUWI          2
# AXL            1
# Ultimus        1
# ALIENWARE      1
# Name: count, dtype: int64

# %%
df["Operating System"].value_counts()
# Out:
# Operating System
# Windows11       861
# Windows10        65
# Mac              24
# Chrome           11
# DOS              10
# Prime             1
# Android           1
# Linux/Ubuntu      1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Price Company Operating System  RAM   Type  Warranty  Inches TouchScreen  \
# 0  58990      HP        Windows11    8    N\A         1      16          NO
# 1  57990      HP        Windows11   16    N\A         1      16          NO
# 2  34490  Lenovo        Windows11    8    N\A         1      15          NO
# 3  32990      HP        Windows11    8    N\A         1      15          NO
# 4  54990    Acer        Windows11    8  Swift         1      14          NO
#
#    HDD    SSD  Generation Processor Type
# 0    0  512.0          11             i5
# 1    0  512.0          11             i5
# 2    0  512.0           0        Ryzen 5
# 3    0  512.0           0        Ryzen 3
# 4    0  512.0          12             i5

# %%
df.dtypes
# Out:
# Price                 int64
# Company              object
# Operating System     object
# RAM                   int64
# Type                 object
# Warranty              int64
# Inches                int64
# TouchScreen          object
# HDD                   int64
# SSD                 float64
# Generation            int64
# Processor Type       object
# dtype: object

# %%
df_encoded = pd.get_dummies(df, columns=['Company', 'Operating System', 'Type', 'TouchScreen', 'Processor Type'], drop_first=True)

# %%
sns.heatmap(df_encoded.corr())
# Out:
# <Axes: >

# %%
df_encoded.corr()["Price"]
# Out:
# Price                     1.000000
# RAM                       0.632041
# Warranty                       NaN
# Inches                    0.120184
# HDD                      -0.039335
#                             ...
# Processor Type_Ryzen 9    0.281851
# Processor Type_i3        -0.259331
# Processor Type_i5        -0.073016
# Processor Type_i7         0.468664
# Processor Type_i9         0.343168
# Name: Price, Length: 62, dtype: float64

# %%
import numpy as np
X = df.drop(columns=["Price", "Warranty"])
y = np.log(df["Price"])

# %%
X
# Out:
#     Company Operating System  RAM   Type  Inches TouchScreen  HDD     SSD  \
# 0        HP        Windows11    8    N\A      16          NO    0   512.0
# 1        HP        Windows11   16    N\A      16          NO    0   512.0
# 2    Lenovo        Windows11    8    N\A      15          NO    0   512.0
# 3        HP        Windows11    8    N\A      15          NO    0   512.0
# 4      Acer        Windows11    8  Swift      14          NO    0   512.0
# ..      ...              ...  ...    ...     ...         ...  ...     ...
# 969    DELL        Windows11   16    XPS      13         YES    0   512.0
# 970      HP        Windows11    8    N\A      15          NO    0   512.0
# 971     MSI        Windows11   16    N\A      15          NO    0   512.0
# 972  Lenovo        Windows11   16    N\A      14          NO    0   512.0
# 973     MSI        Windows11   16    N\A      16          NO    0  1024.0
#
#      Generation Processor Type
# 0            11             i5
# 1            11             i5
# 2             0        Ryzen 5
# 3             0        Ryzen 3
# 4            12             i5
# ..          ...            ...
# 969          12             i5
# 970           0        Ryzen 3
# 971           0        Ryzen 7
# 972          12             i7
# 973          13             i7
#
# [974 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=2)

# %%
X_train
# Out:
#      Company Operating System  RAM     Type  Inches TouchScreen   HDD    SSD  \
# 396       HP        Windows11    8      N\A      15          NO     0  512.0
# 595   Lenovo        Windows11   16  IdeaPad      14          NO     0  512.0
# 142       HP        Windows10    8      N\A      15          NO  1024    NaN
# 279      MSI        Windows11    8      N\A      14          NO     0  512.0
# 496       HP        Windows11    8      N\A      15          NO     0  512.0
# ..       ...              ...  ...      ...     ...         ...   ...    ...
# 534       HP        Windows11    8      N\A      15          NO     0  512.0
# 584   Lenovo        Windows11   16      N\A      15          NO     0  512.0
# 493       HP        Windows11    8      N\A      15          NO     0  512.0
# 527  SAMSUNG        Windows11   16      N\A      15          NO     0  512.0
# 168   Lenovo        Windows11   16  IdeaPad      15          NO     0  512.0
#
#      Generation Processor Type
# 396          12             i5
# 595           0        Ryzen 5
# 142          11             i3
# 279           0        Ryzen 5
# 496          11             i3
# ..          ...            ...
# 534          12             i5
# 584          12             i5
# 493           0        Ryzen 5
# 527          13             i7
# 168          11             i5
#
# [827 rows x 10 columns]
